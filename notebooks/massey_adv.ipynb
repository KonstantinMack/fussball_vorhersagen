# %%
import os
import pickle
import pandas as pd
import numpy as np
from sklearn import linear_model
from scipy.stats import poisson
import matplotlib.pyplot as plt

# %%
def save_obj(obj, name):
    with open('C:/Users/Konny/DataScience/SpicedAcademy/fussball_vorhersagen/data/' + name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open('C:/Users/Konny/DataScience/SpicedAcademy/fussball_vorhersagen/data/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
data = load_obj("Eng17")

# %%
def get_team_encoding(df):
    labels, levels = pd.factorize(pd.concat([df["HomeTeam"], df["AwayTeam"]]))
    club_dict = dict(zip(levels, range(len(set(levels)))))
    df["HomeId"] = df["HomeTeam"].map(club_dict)
    df["AwayId"] = df["AwayTeam"].map(club_dict)
    df["Result"] = df["FTHG"] - df["FTAG"]
    df["round"] = df["round"].apply(int)
    return df

# %%
def buildGamesMatrix3(games, num_teams):
    l = len(games)
    M = np.zeros([l*2, num_teams*2+1])
    R = np.zeros([l*2])
    for i, j in enumerate(games):
        M[i, j[0]] += 1
        M[i, j[1]+num_teams] += -1
        M[i, num_teams*2] += 1
        M[l+i, j[1]] += 1
        M[l+i, j[0]+num_teams] += -1
        R[i] += j[2]
        R[l+i] += j[3]
    return M, R

# %%
def get_ratings(df):
    df2 = df[["HomeId", "AwayId", "FTHG", "FTAG"]]
    M, R = buildGamesMatrix3(df2.values,20)
    clf = linear_model.Ridge(fit_intercept=False, alpha=0.1)
    clf.fit(M,R)
    ratings = clf.coef_
    correction = np.min(ratings[20:40])
    ratings[0:40] -= correction
    rat_off_dict = dict(zip(range(20),np.round(ratings[:20], 4)))
    rat_def_dict = dict(zip(range(20),np.round(ratings[20:40], 4)))
    rat_hfa = np.round(ratings[40], 4)
    return rat_off_dict, rat_def_dict, rat_hfa

# %%
def get_all_matchday_ratings(df):
    rat_offense_full = {}
    rat_defense_full = {}
    rat_hfa_full = {}
    for i in range(1, df["round"].max() + 1):
        matchday = df[df["round"] <= i].copy()
        offense, defense, hfa = get_ratings(matchday)
        rat_offense_full[i] = offense
        rat_defense_full[i] = defense
        rat_hfa_full[i] = hfa
    return rat_offense_full, rat_defense_full, rat_hfa_full

# %%
def get_exp_goals(df):
    df["exp_HG"] = np.where(df["Home_Off_Rat"] - df["Away_Def_Rat"] + df["HFA"] > 0, df["Home_Off_Rat"] - df["Away_Def_Rat"] + df["HFA"], 0)
    df["exp_AG"] = np.where(df["Away_Off_Rat"] - df["Home_Def_Rat"] > 0, df["Away_Off_Rat"] - df["Home_Def_Rat"], 0)
    df["exp_GD"] = df["exp_HG"] - df["exp_AG"]
    return df

# %%
def get_massey(df):
    df = get_team_encoding(df)
    rat_offense_full, rat_defense_full, hfa = get_all_matchday_ratings(df)
    home_off = [df[df["round"] == i+1].HomeId.map(j) for i, j in rat_offense_full.items()]
    away_off = [df[df["round"] == i+1].AwayId.map(j) for i, j in rat_offense_full.items()]
    home_def = [df[df["round"] == i+1].HomeId.map(j) for i, j in rat_defense_full.items()]
    away_def = [df[df["round"] == i+1].AwayId.map(j) for i, j in rat_defense_full.items()]
    home_off_rat = pd.DataFrame(pd.concat(home_off))
    home_off_rat.columns = ["Home_Off_Rat"]
    away_off_rat = pd.DataFrame(pd.concat(away_off))
    away_off_rat.columns = ["Away_Off_Rat"]
    home_def_rat = pd.DataFrame(pd.concat(home_def))
    home_def_rat.columns = ["Home_Def_Rat"]
    away_def_rat = pd.DataFrame(pd.concat(away_def))
    away_def_rat.columns = ["Away_Def_Rat"]
    hfa = pd.DataFrame(pd.Series(hfa), columns=["HFA"]).shift()
    df = df.merge(home_off_rat, left_index=True, right_index=True, how="left")
    df = df.merge(away_off_rat, left_index=True, right_index=True, how="left")
    df = df.merge(home_def_rat, left_index=True, right_index=True, how="left")
    df = df.merge(away_def_rat, left_index=True, right_index=True, how="left")
    df = df.merge(hfa, how="left", left_on="round", right_index=True)
    df = get_exp_goals(df)
    return df

# %%
test = get_massey(data)

# %%
test
# Out:
#       _id          away_player1          away_player10        away_player11  \
# 0    1125     Kasper Schmeichel             Ahmed Musa          Jamie Vardy
# 1    1079        Heurelho Gomes            Troy Deeney         Odion Ighalo
# 2    1057            Ben Foster    Jose Salomon Rondon       Saido Berahino
# 3    1064            Shay Given            Bojan Krkic     Mame Biram Diouf
# 4    1123      Lukasz Fabianski        Wayne Routledge         Modou Barrow
# 5    1140           Hugo Lloris      Christian Eriksen           Harry Kane
# 6    1076          Vito Mannone         Duncan Watmore        Jermain Defoe
# 7    1061          David De Gea      Marouane Fellaini   Zlatan Ibrahimovic
# 8    1139        Simon Mignolet        Roberto Firmino           Sadio Mane
# 9    1053                Adrian         Enner Valencia           Andre Ayew
# 10   1122        Fraser Forster             Shane Long       Nathan Redmond
# 11   1072    Wilfredo Caballero            Fernandinho        Sergio Aguero
# 12   1050      Thibaut Courtois          Nemanja Matic          Diego Costa
# 13   1119       Wayne Hennessey         Jason Puncheon       Connor Wickham
# 14   1056        Simon Mignolet        Roberto Firmino     Daniel Sturridge
# 15   1138  Maarten Stekelenburg           Gareth Barry      Gerard Deulofeu
# 16   1069       Eldin Jakupovic       Robert Snodgrass       Adama Diomande
# 17   1052             Petr Cech       Francis Coquelin       Alexis Sanchez
# 18   1137            Brad Guzan           Adam Forshaw       Alvaro Negredo
# 19   1046           Artur Boruc            Joshua King           Jordon Ibe
# 20   1117        Simon Mignolet        Roberto Firmino           Sadio Mane
# 21   1065            Tom Heaton             Andre Gray            Sam Vokes
# 22   1042            Shay Given       Mame Biram Diouf         Peter Crouch
# 23   1067             Petr Cech           Granit Xhaka       Alexis Sanchez
# 24   1115           Artur Boruc            Joshua King           Jordon Ibe
# 25   1048       Jordan Pickford           Fabio Borini        Jermain Defoe
# 26   1136      Lukasz Fabianski              Jack Cork    Fernando Llorente
# 27   1043          David De Gea      Marouane Fellaini   Zlatan Ibrahimovic
# 28   1135            Brad Guzan           Adam Forshaw       Alvaro Negredo
# 29   1038                Adrian         Enner Valencia      Ashley Fletcher
# 371        Erik Pieters            Joe Allen             Glenn Whelan   ...
# 372        Martin Kelly       James McArthur         Luka Milivojevic   ...
# 373        Craig Dawson        Claudio Yacob           James Morrison   ...
# 374          Adam Smith          Dan Gosling            Andrew Surman   ...
# 375          Ben Davies        Heung-Min Son           Victor Wanyama   ...
# 376     Aaron Cresswell       Manuel Lanzini                Sam Byram   ...
# 377        Bryan Oviedo       Lee Cattermole        Sebastian Larsson   ...
# 378    Nicolas Otamendi      Kevin De Bruyne               Leroy Sane   ...
# 379      Calum Chambers     Grant Leadbitter             Adam Clayton   ...
#
#     AwayId Result Home_Off_Rat Away_Off_Rat Home_Def_Rat Away_Def_Rat     HFA  \
# 0       16      1          NaN          NaN          NaN          NaN     NaN
# 1       12      0          NaN          NaN          NaN          NaN     NaN
# 2       14     -1          NaN          NaN          NaN          NaN     NaN
# 3       11      0          NaN          NaN          NaN          NaN     NaN
# 4       15     -1          NaN          NaN          NaN          NaN     NaN
# 5       13      0          NaN          NaN          NaN          NaN     NaN
# 6       17      1          NaN          NaN          NaN          NaN     NaN
# 7       10     -2          NaN          NaN          NaN          NaN     NaN
# 8       19     -1          NaN          NaN          NaN          NaN     NaN
# 9       18      1          NaN          NaN          NaN          NaN     NaN
# 10       1      2       3.3333       1.8693       1.9402       1.4286  1.0744
# 11       6     -3       2.3810       2.3455       1.9402       1.4286  1.0744
# 12       9     -1       2.3810       2.3455       1.9402       1.4286  1.0744
# 13       2      1       2.3810       1.3932       1.9402       1.4286  1.0744
# 14      19      2       1.3932       3.8095       1.4286       0.9878  1.0744
# 15       5     -1       2.3810       1.8693       2.4164       1.4286  1.0744
# 16       0     -2       2.3810       2.3455       2.4164       1.4286  1.0744
# 17       8      0       2.3810       2.8217       1.4640       0.0000  1.0744
# 18       3     -1       2.3810       1.8693       1.4640       1.4286  1.0744
# 19       7      1       2.3810       1.8693       1.4640       0.4762  1.0744
# 20      19      0       2.9923       3.8200       2.2397       0.0000 -0.2811
# 21       4      3       3.9308       2.4379       1.6650       2.8995 -0.2811
# 22      11      1       3.5847       2.9923       1.8796       1.0318 -0.2811
# 23       8     -2       2.9137       2.8807       1.5570       0.8789 -0.2811
# 24       7      0       2.1561       2.6698       1.8796       1.3131 -0.2811
# 25      17      0       2.3765       2.9923       1.9290       1.5080 -0.2811
# 26      15      1       2.0631       3.0253       2.5247       2.3139 -0.2811
# 27      10     -1       4.4587       4.1747       1.9290       1.9089 -0.2811
# 28       3      0       2.9923       2.8878       1.7635       1.8796 -0.2811
# 29      18      2       4.3164       2.6204       1.8796       2.1729 -0.2811
# ..     ...    ...          ...          ...          ...          ...     ...
# 350      5      1       1.5227       2.0551       0.0000       0.7665  0.4088
# 351      1      0       2.3653       1.4367       0.7372       0.6437  0.4088
# 352     10      2       2.2548       1.7372       0.7120       1.1797  0.4088
# 353      3      3       2.4930       1.0515       1.0274       0.6520  0.4088
# 354      8     -2       1.5753       2.6011       0.8502       0.9383  0.3830
# 355     12      1       1.9666       1.4252       0.7498       0.1803  0.4308
# 356  0.9042  1.9075 -1.0033
# 357  2.5358  0.7763  1.7595
# 358  1.7000  1.2421  0.4579
# 359  0.7707  0.7749 -0.0042
# 360  1.5064  1.2760  0.2304
# 361  1.1012  1.7579 -0.6567
# 362  2.0313  1.0939  0.9374
# 363  1.2635  1.9983 -0.7348
# 364  1.6918  0.4656  1.2262
# 365  2.6209  0.3559  2.2650
# 366  2.5520  0.4645  2.0875
# 367  1.9955  0.5936  1.4019
# 368  0.7321  1.0771 -0.3450
# 369  0.7799  2.0778 -1.2979
# 370  1.9476  1.2237  0.7239
# 371  1.4213  0.7236  0.6977
# 372  1.8536  0.5259  1.3277
# 373  1.3193  1.3828 -0.0635
# 374  1.9105  1.5541  0.3564
# 375  0.5211  2.4743 -1.9532
# 376  1.5494  1.0354  0.5140
# 377  2.6857  0.0458  2.6399
# 378  0.9996  2.1130 -1.1134
# 379  2.1716  0.2666  1.9050
#
# [380 rows x 141 columns]

# %%
def get_probs(H_xG, A_xG):
    """
    Takes expected goals for home and away team, and calculates
    probabilities for home win, draw and away win by using a poisson
    distribution
    """
    goals_home = []
    goals_away = []
    for i in range(8):
        goals_home.append(poisson.pmf(i, H_xG))
        goals_away.append(poisson.pmf(i, A_xG))
    row = pd.Series(goals_home, index=np.arange(0, 8))
    col = pd.Series(goals_away, index=np.arange(0, 8))
    df = row.apply(lambda r: r * col)
    home = sum(sum(np.tril(df, -1)))
    away = sum(sum(np.triu(df, 1)))
    draw = 1 - home - away
    return np.round(home, 4), np.round(draw, 4), np.round(away, 4)

# %%
test["H_pred_Poi"], test["D_pred_Poi"], test["A_pred_Poi"] = get_probs(test["exp_HG"], test["exp_AG"])

# %%
test.tail()
# Out:
#      _id        away_player1      away_player10  away_player11  \
# 375  843         Hugo Lloris  Christian Eriksen     Harry Kane
# 376  764              Adrian   Robert Snodgrass     Andre Ayew
# 377  769     Jordan Pickford      Adnan Januzaj   Fabio Borini
# 378  859  Wilfredo Caballero         Yaya Toure  Sergio Aguero
# 379  762          Brad Guzan       Adam Forshaw   Rudy Gestede
#
#           away_player2           away_player3     away_player4  \
# 375  Toby Alderweireld         Jan Vertonghen  Kieran Trippier
# 376      James Collins  Angelo Obinze Ogbonna       Jose Fonte
# 377        Billy Jones         Joleon Lescott      John O'Shea
# 378    Vincent Kompany            Gael Clichy      Fernandinho
# 379              Fabio          George Friend       Ben Gibson
#
#          away_player5      away_player6       away_player7    ...      \
# 375        Ben Davies     Heung-Min Son     Victor Wanyama    ...
# 376   Aaron Cresswell    Manuel Lanzini          Sam Byram    ...
# 377      Bryan Oviedo    Lee Cattermole  Sebastian Larsson    ...
# 378  Nicolas Otamendi   Kevin De Bruyne         Leroy Sane    ...
# 379    Calum Chambers  Grant Leadbitter       Adam Clayton    ...
#
#     Away_Off_Rat Home_Def_Rat Away_Def_Rat     HFA  exp_HG  exp_AG  exp_GD  \
# 375       2.4743       0.0000       1.2526  0.4135  0.5211  2.4743 -1.9532
# 376       1.5955       0.5601       0.2744  0.4135  1.5494  1.0354  0.5140
# 377       1.1250       1.0792       0.2430  0.4135  2.6857  0.0458  2.6399
# 378       2.3795       0.2665       0.8776  0.4135  0.9996  2.1130 -1.1134
# 379       1.0844       0.8178       0.6261  0.4135  2.1716  0.2666  1.9050
#
#     H_pred_Poi D_pred_Poi A_pred_Poi
# 375     0.0589     0.1425     0.7985
# 376     0.4919     0.2547     0.2534
# 377     0.9170     0.0798     0.0032
# 378     0.1695     0.2029     0.6276
# 379     0.8177     0.1475     0.0348
#
# [5 rows x 144 columns]

# %%
test["Home"] = np.where(test["FTHG"] > test["FTAG"], 1, 0)
test["Draw"] = np.where(test["FTHG"] == test["FTAG"], 1, 0)
test["Away"] = np.where(test["FTHG"] < test["FTAG"], 1, 0)

# %%
def rps(prob_h, prob_d, prob_a, home, draw, away):
    """
    Calculates the rank probability score
    prob_h/d/a -> predicted probability
    home/draw/away -> 0 or 1 for actual result
    The lower RPS the better
    """
    step1 = prob_h - home
    step2 = prob_d - draw
    summe = step1 + step2
    rps = (step1 ** 2 + summe ** 2) / 2
    return rps

# %%
test["rps_poi"] = rps(test["H_pred_Poi"], test["D_pred_Poi"], test["A_pred_Poi"], test["Home"],test["Draw"],test["Away"])

# %%
test.tail()
# Out:
#      _id        away_player1      away_player10  away_player11  \
# 375  843         Hugo Lloris  Christian Eriksen     Harry Kane
# 376  764              Adrian   Robert Snodgrass     Andre Ayew
# 377  769     Jordan Pickford      Adnan Januzaj   Fabio Borini
# 378  859  Wilfredo Caballero         Yaya Toure  Sergio Aguero
# 379  762          Brad Guzan       Adam Forshaw   Rudy Gestede
#
#           away_player2           away_player3     away_player4  \
# 375  Toby Alderweireld         Jan Vertonghen  Kieran Trippier
# 376      James Collins  Angelo Obinze Ogbonna       Jose Fonte
# 377        Billy Jones         Joleon Lescott      John O'Shea
# 378    Vincent Kompany            Gael Clichy      Fernandinho
# 379              Fabio          George Friend       Ben Gibson
#
#          away_player5      away_player6       away_player7    ...     exp_HG  \
# 375        Ben Davies     Heung-Min Son     Victor Wanyama    ...     0.5211
# 376   Aaron Cresswell    Manuel Lanzini          Sam Byram    ...     1.5494
# 377      Bryan Oviedo    Lee Cattermole  Sebastian Larsson    ...     2.6857
# 378  Nicolas Otamendi   Kevin De Bruyne         Leroy Sane    ...     0.9996
# 379    Calum Chambers  Grant Leadbitter       Adam Clayton    ...     2.1716
#
#      exp_AG  exp_GD H_pred_Poi D_pred_Poi A_pred_Poi Home Draw Away       rps
# 375  2.4743 -1.9532     0.0589     0.1425     0.7985    0    0    1  0.022016
# 376  1.0354  0.5140     0.4919     0.2547     0.2534    0    0    1  0.399689
# 377  0.0458  2.6399     0.9170     0.0798     0.0032    1    0    0  0.003450
# 378  2.1130 -1.1134     0.1695     0.2029     0.6276    0    0    1  0.083706
# 379  0.2666  1.9050     0.8177     0.1475     0.0348    1    0    0  0.017222
#
# [5 rows x 148 columns]

# %%
test[(test["round"] >= 7) & (test["round"] <=34)]["rps"].mean()
# Out:
# 0.1889678365714286
